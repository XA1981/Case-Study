# %%
import pandas as pd 
 
dmd = pd.read_csv("D:/Case Study/Promotional Channels/DMD/Preformist Terrain Email HCP Level Report.csv") 

dmd.head()
# Out:
#    DMD JOB ID  CLIENT JOBID  DEA NUMBER EVENT TYPE  COUNT  EVENT DATE  \
# 0       88472           NaN      139969  DELIVERED    NaN  2016-11-08
# 1       88472           NaN      147366  DELIVERED    NaN  2016-11-08
# 2       88472           NaN      156043  DELIVERED    NaN  2016-11-08
# 3       88472           NaN      156119  DELIVERED    NaN  2016-11-08
# 4       88472           NaN      159749  DELIVERED    NaN  2016-11-08
#
#   CLICK LINK  ENGAGEMENT PLATFORM ID  Unnamed: 8  Unnamed: 9 Unnamed: 10
# 0        NaN                     NaN         NaN         NaN  2016-11-08
# 1        NaN                     NaN         NaN         NaN         NaN
# 2        NaN                     NaN         NaN         NaN         NaN
# 3        NaN                     NaN         NaN         NaN         NaN
# 4        NaN                     NaN         NaN         NaN         NaN

# %%
from datetime import datetime
from datetime import timedelta
a=dmd.loc[:,'EVENT DATE']
#type(a[1])

# %%
for i in range(0,len(a)):
    x=str.split(a[i])[0]
    tmp=datetime.strptime(x,'%Y-%m-%d')
    week_day=tmp.weekday()
    if(week_day!=4):
        tmp=tmp+timedelta(days=4-week_day)
        #tmp=datetime.strptime(tmp,'%Y-%m-%d')
        a[i]=""+str(tmp)
    else:
        #tmp=datetime.strptime(tmp,'%Y-%m-%d')
        a[i]=""+str(tmp)
# Out:
# c:\users\a1981\appdata\local\programs\python\python37-32\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print(a)
# Out:
# 0        2016-11-11 00:00:00
# 1        2016-11-11 00:00:00
# 2        2016-11-11 00:00:00
# 3        2016-11-11 00:00:00
# 4        2016-11-11 00:00:00
# 5        2016-11-11 00:00:00
# 6        2016-11-11 00:00:00
# 7        2016-11-11 00:00:00
# 8        2016-11-11 00:00:00
# 9        2016-11-11 00:00:00
# 10       2016-11-11 00:00:00
# 11       2016-11-11 00:00:00
# 12       2016-11-11 00:00:00
# 13       2016-11-11 00:00:00
# 14       2016-11-11 00:00:00
# 15       2016-11-11 00:00:00
# 16       2016-11-11 00:00:00
# 17       2016-11-11 00:00:00
# 18       2016-11-11 00:00:00
# 19       2016-11-11 00:00:00
# 20       2016-11-11 00:00:00
# 21       2016-11-11 00:00:00
# 22       2016-11-11 00:00:00
# 23       2016-11-11 00:00:00
# 24       2016-11-11 00:00:00
# 25       2016-11-11 00:00:00
# 26       2016-11-11 00:00:00
# 27       2016-11-11 00:00:00
# 28       2016-11-11 00:00:00
# 29       2016-11-11 00:00:00
#                 ...
# 19573    2016-11-11 00:00:00
# ...

# %%
new_dmd = pd.DataFrame({'EVENT DATE': a})

# %%
dmd.update (new_dmd)

# %%
dmd
# Out:
#        DMD JOB ID  CLIENT JOBID  DEA NUMBER           EVENT TYPE  COUNT  \
# 0           88472           NaN      139969            DELIVERED    NaN
# 1           88472           NaN      147366            DELIVERED    NaN
# 2           88472           NaN      156043            DELIVERED    NaN
# 3           88472           NaN      156119            DELIVERED    NaN
# 4           88472           NaN      159749            DELIVERED    NaN
# 5           88472           NaN      159749  ENGAGEMENT_PLATFORM    NaN
# 6           88472           NaN      159749               OPENED    1.0
# 7           88472           NaN      160299            DELIVERED    NaN
# 8           88472           NaN      160484            DELIVERED    NaN
# 9           88472           NaN      160651            DELIVERED    NaN
# 10          88472           NaN      164415            DELIVERED    NaN
# 11          88472           NaN      165200            DELIVERED    NaN
# ...

# %%
from datetime import datetime
from datetime import timedelta
def change_date(dataName,colName ):
    a=dataName.loc[:,colName]
    for i in range(0,len(a)):
        x=str.split(a[i])[0]
        tmp=datetime.strptime(x,'%Y-%m-%d')
        week_day=tmp.weekday()
        if(week_day!=4):
            tmp=tmp+timedelta(days=4-week_day)
            #tmp=datetime.strptime(tmp,'%Y-%m-%d')
            a[i]=""+str(tmp)
        else:
            #tmp=datetime.strptime(tmp,'%Y-%m-%d')
            a[i]=""+str(tmp)
    new_dataFrame = pd.DataFrame({colName: a})
    dataName.update (new_dataFrame)
    return dataname

# call function in the format
#DataFrameName=change_date(DataFrameName,colName_having_date)
